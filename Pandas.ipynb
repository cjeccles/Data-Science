# %% [markdown]
# <h1>Pandas and matplotlib</h1>
# Pandas is arguably the most used library in data science and most visualisations in python are made using matplotlib. They are also incredibly important to Machine Learning as they allow one to explore the data (and formulate the questions based on it) and also CLEAN/PREPARE the data. It is not an exageration saying that 80-90% of the work done by a Data Scientist is cleaning data.
#
# [pandas](https://pandas.pydata.org/) is a powerful library that allows one to work with data.

# %%
pip install seaborn
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in f:\python3120\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in f:\python3120\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in f:\python3120\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in f:\python3120\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in f:\python3120\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\python3120\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\python3120\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\cjecc\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in f:\python3120\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\python3120\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cjecc\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in f:\python3120\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in f:\python3120\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\cjecc\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    --------------------------------------- 294.6/294.6 kB 19.0 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# To open our dataset let us use [pd.read csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
pokemon_df = pd.read_csv('Pokemon.csv', sep=',')

# %% [markdown]
# Question: df stands for dataframe but what is a dataframe?

# %% [markdown]
# Question: how do we print the dataframe? When is that convenient?

# %%
print(pokemon_df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Being able to see the entirety of the data on the screen is a double edged sword. In one hand the human working on a given dataset can be there visually inspecting the dataset all the time. On the other hand this process of merely displaying the data can quickly become a burden to the processing time. It is then more practical to use a different approach when dealing with large datasets.<br>
#
# In this sense there are a few tools we can use to inspect the data for example [head](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) and [tail](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html).

# %%
# Displaying the first 5 rows of the dataframe.
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Displaying the bottom 5 rows of the dataframe.
pokemon_df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# Another very powerful tool is [describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# Question: what are we seeing above? How is that useful? How is that NOT useful?

# %% [markdown]
# It is also possible to query specific aspects of each individual column. To select only a column it is similar to getting a specific item of a dictionary,

# %%
# Getting only the items that are in the HP column.
pokemon_df['HP']
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
pokemon_df.HP
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
# A list of columns can also be selected.
pokemon_df[['HP','Attack','Speed']]
# Out:
#      HP  Attack  Speed
# 0    45      49     45
# 1    60      62     60
# 2    80      82     80
# 3    80     100     80
# 4    39      52     65
# ..   ..     ...    ...
# 795  50     100     50
# 796  50     160    110
# 797  80     110     70
# 798  80     160     80
# 799  80     110     70
#
# [800 rows x 3 columns]

# %% [markdown]
# To get to know all keys of the dataframe (or for getting something you can quick copy and paste) you can use

# %%
# This also works on dictionaries!
pokemon_df.keys()
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon_df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# For non-numerical columns other tools are more appropriated to understand the value distribution, such as

# %%
# This shows all the unique entries in the dataset for that column.
pokemon_df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
# This will count how much incidence of a given unique entry is seen on the dataframe.
pokemon_df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# Exercises: how many pokemons does each different generation have? Also, how many legendary pokemons are there in total?

# %%
pokemon_df['Generation'].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
pokemon_df['Legendary'].value_counts()
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %% [markdown]
# This is how we save our dataframe.

# %%
#Exporting data.
pokemon_df.to_csv('mypokemondataset.csv', sep=',')

# %% [markdown]
# Describing the dataset.

# %%
# Getting the description.
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# Question: what is all this information above?

# %%
# Combining methods.
pokemon_df.describe().to_csv('description.csv')

# %% [markdown]
# Now to operate over a single column the operands we've seen so far work,

# %%
pokemon_df['HP']+5
# Out:
# 0      50
# 1      65
# 2      85
# 3      85
# 4      44
#        ..
# 795    55
# 796    55
# 797    85
# 798    85
# 799    85
# Name: HP, Length: 800, dtype: int64

# %% [markdown]
# Question: Did the operation above changed the actual values in the dataframe?

# %%
pokemon_df['HP']
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %% [markdown]
# Creating a new column in a dataframe is quite simple,

# %%
pokemon_df['Irrelevant'] = np.nan
pokemon_df['HP+100'] = pokemon_df['HP'] + 100

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100
# 0       65       65     45           1      False         NaN     145
# 1       80       80     60           1      False         NaN     160
# 2      100      100     80           1      False         NaN     180
# 3      122      120     80           1      False         NaN     180
# 4       60       50     65           1      False         NaN     139

# %%
pokemon_df['Atk+Def+HP'] = pokemon_df['Attack'] + pokemon_df['Defense'] + pokemon_df['HP']

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Irrelevant  HP+100  \
# 0       65       65     45           1      False         NaN     145
# 1       80       80     60           1      False         NaN     160
# 2      100      100     80           1      False         NaN     180
# 3      122      120     80           1      False         NaN     180
# 4       60       50     65           1      False         NaN     139
#
#    Atk+Def+HP
# 0         143
# 1         185
# 2         245
# 3         303
# 4         134

# %% [markdown]
# As it is dropping those columns with [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)

# %%
# Getting the column names for a copy paste
pokemon_df.keys()
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Irrelevant',
#        'HP+100', 'Atk+Def+HP'],
#       dtype='object')

# %%
# Listing the columns to drop. 
# axis = 1 means we're dropping it column-wise.
pokemon_df.drop(['Irrelevant','HP+100'], axis=1)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP
# 0         65       65     45           1      False         143
# 1         80       80     60           1      False         185
# 2        100      100     80           1      False         245
# 3        122      120     80           1      False         303
# 4         60       50     65           1      False         134
# ..       ...      ...    ...         ...        ...         ...
# 795      100      150     50           6       True         300
# 796      160      110    110           6       True         320
# 797      150      130     70           6       True         250
# 798      170      130     80           6       True         300
# 799      130       90     70           6       True         310
#
# [800 rows x 14 columns]

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP
# 0       65       65     45           1      False         143
# 1       80       80     60           1      False         185
# 2      100      100     80           1      False         245
# 3      122      120     80           1      False         303
# 4       60       50     65           1      False         134

# %%
# Modifying a specific datapoint.
pokemon_df.at[0,'Irrelevant'] = 10

# %% [markdown]
# Question: why are the columns still there then? how do we actually get rid of them?

# %%
pokemon_df = pokemon_df.drop(['Irrelevant', 'HP+100'], axis=1)

# %% [markdown]
# Exercise: create a new column where the Attack of each pokemon is divided by the maximum value on the attack column, and a new column containing the division of the attack and defense stats.

# %%
pokemon_df['Atk_Percent'] = pokemon_df['Attack'] / pokemon_df['Attack'].max()
pokemon_df['Atk/Def'] = pokemon_df['Attack'] / pokemon_df['Defense']

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  Atk_Percent  \
# 0       65       65     45           1      False         143     0.257895
# 1       80       80     60           1      False         185     0.326316
# 2      100      100     80           1      False         245     0.431579
# 3      122      120     80           1      False         303     0.526316
# 4       60       50     65           1      False         134     0.273684
#
#     Atk/Def
# 0  1.000000
# 1  0.984127
# 2  0.987952
# 3  0.813008
# 4  1.209302

# %% [markdown]
# Filtering is also a process where a data scientist can spend countless hours in. Using pandas the process is also quite simple.

# %%
# Showcase the pokemons with HP larger than 80.
pokemon_df[pokemon_df['HP'] > 80]
# Out:
#        #                 Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 22    18              Pidgeot  Normal  Flying    479   83      80       75
# 23    18  PidgeotMega Pidgeot  Normal  Flying    579   83      80       80
# 36    31            Nidoqueen  Poison  Ground    505   90      92       87
# 39    34             Nidoking  Poison  Ground    505   81     102       77
# 41    36             Clefable   Fairy     NaN    483   95      70       73
# ..   ...                  ...     ...     ...    ...  ...     ...      ...
# 789  713              Avalugg     Ice     NaN    514   95     117      184
# 791  715              Noivern  Flying  Dragon    535   85      70       80
# 792  716              Xerneas   Fairy     NaN    680  126     131       95
# 793  717              Yveltal    Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  Atk_Percent  \
# 22        70       70    101           1      False         238     0.421053
# 23       135       80    121           1      False         243     0.421053
# 36        75       85     76           1      False         269     0.484211
# 39        85       75     85           1      False         260     0.536842
# 41        95       90     60           1      False         238     0.368421
# ..       ...      ...    ...         ...        ...         ...          ...
# 789       44       46     28           6      False         396     0.615789
# 791       97       80    123           6      False         235     0.368421
# 792      131       98     99           6       True         352     0.689474
# 793      131       98     99           6       True         352     0.689474
# 794       81       95     95           6       True         329     0.526316
#
#       Atk/Def
# 22   1.066667
# 23   1.000000
# 36   1.057471
# 39   1.324675
# 41   0.958904
# ..        ...
# 789  0.635870
# 791  0.875000
# 792  1.378947
# 793  1.378947
# 794  0.826446
#
# [193 rows x 16 columns]

# %%
# Notice that the condition doesn't need to be numerical.
pokemon_df[pokemon_df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# 147  136                    Flareon   Fire       NaN    525   65     130
# 158  146                    Moltres   Fire    Flying    580   90     100
# 169  155                  Cyndaquil   Fire       NaN    309   39      52
# 170  156                    Quilava   Fire       NaN    405   58      64
# 171  157                 Typhlosion   Fire       NaN    534   78      84
# 236  218                     Slugma   Fire       NaN    250   40      40
# 237  219                   Magcargo   Fire      Rock    410   50      50
# 259  240                      Magby   Fire       NaN    365   45      75
# 263  244                      Entei   Fire       NaN    580  115     115
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 276  255                    Torchic   Fire       NaN    310   45      60
# 277  256                  Combusken   Fire  Fighting    405   60      85
# 278  257                   Blaziken   Fire  Fighting    530   80     120
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 352  322                      Numel   Fire    Ground    305   60      60
# 353  323                   Camerupt   Fire    Ground    460   70     100
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70     120
# 355  324                    Torkoal   Fire       NaN    470   70      85
# 435  390                   Chimchar   Fire       NaN    309   44      58
# 436  391                   Monferno   Fire  Fighting    405   64      78
# 437  392                  Infernape   Fire  Fighting    534   76     104
# 518  467                  Magmortar   Fire       NaN    540   75      95
# 542  485                    Heatran   Fire     Steel    600   91      90
# 557  498                      Tepig   Fire       NaN    308   65      63
# 558  499                    Pignite   Fire  Fighting    418   90      93
# 559  500                     Emboar   Fire  Fighting    528  110     123
# 572  513                    Pansear   Fire       NaN    316   50      53
# 573  514                   Simisear   Fire       NaN    498   75      98
# 614  554                   Darumaka   Fire       NaN    315   70      90
# 615  555    DarmanitanStandard Mode   Fire       NaN    480  105     140
# 616  555         DarmanitanZen Mode   Fire   Psychic    540  105      30
# 692  631                    Heatmor   Fire       NaN    484   85      97
# 721  653                   Fennekin   Fire       NaN    307   40      45
# 722  654                    Braixen   Fire       NaN    409   59      59
# 723  655                    Delphox   Fire   Psychic    534   75      69
# 730  662                Fletchinder   Fire    Flying    382   62      73
# 731  663                 Talonflame   Fire    Flying    499   78      81
# 735  667                     Litleo   Fire    Normal    369   62      50
# 736  668                     Pyroar   Fire    Normal    507   86      68
# 799  721                  Volcanion   Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  \
# 4         43       60       50     65           1      False         134
# 5         58       80       65     80           1      False         180
# 6         78      109       85    100           1      False         240
# 7        111      130       85    100           1      False         319
# 8         78      159      115    100           1      False         260
# 42        40       50       65     65           1      False         119
# 43        75       81      100    100           1      False         224
# 63        45       70       50     60           1      False         170
# 64        80      100       80     95           1      False         280
# 83        55       65       65     90           1      False         190
# 84        70       80       80    105           1      False         235
# 135       57      100       85     93           1      False         217
# 147       60       95      110     65           1      False         255
# 158       90      125       85     90           1       True         280
# 169       43       60       50     65           2      False         134
# 170       58       80       65     80           2      False         180
# 171       78      109       85    100           2      False         240
# 236       40       70       40     20           2      False         120
# 237      120       80       80     30           2      False         220
# 259       37       70       55     83           2      False         157
# 263       85       90       75    100           2       True         315
# 270       90      110      154     90           2       True         326
# 276       40       70       50     45           3      False         145
# 277       60       85       60     55           3      False         205
# 278       70      110       70     80           3      False         270
# 279       80      130       80    100           3      False         320
# 352       40       65       45     35           3      False         160
# 353       70      105       75     40           3      False         240
# 354      100      145      105     20           3      False         290
# 355      140       85       70     20           3      False         295
# 435       44       58       44     61           4      False         146
# 436       52       78       52     81           4      False         194
# 437       71      104       71    108           4      False         251
# 518       67      125       95     83           4      False         237
# 542      106      130      106     77           4       True         287
# 557       45       45       45     45           5      False         173
# 558       55       70       55     55           5      False         238
# 559       65      100       65     65           5      False         298
# 572       48       53       48     64           5      False         151
# 573       63       98       63    101           5      False         236
# 614       45       15       45     50           5      False         205
# 615       55       30       55     95           5      False         300
# 616      105      140      105     55           5      False         240
# 692       66      105       66     65           5      False         248
# 721       40       62       60     60           6      False         125
# 722       58       90       70     73           6      False         176
# 723       72      114      100    104           6      False         216
# 730       55       56       52     84           6      False         190
# 731       71       74       69    126           6      False         230
# 735       58       73       54     72           6      False         170
# 736       72      109       66    106           6      False         226
# 799      120      130       90     70           6       True         310
#
#      Atk_Percent   Atk/Def
# 4       0.273684  1.209302
# 5       0.336842  1.103448
# 6       0.442105  1.076923
# 7       0.684211  1.171171
# 8       0.547368  1.333333
# 42      0.215789  1.025000
# 43      0.400000  1.013333
# 63      0.368421  1.555556
# 64      0.578947  1.375000
# 83      0.447368  1.545455
# 84      0.526316  1.428571
# 135     0.500000  1.666667
# 147     0.684211  2.166667
# 158     0.526316  1.111111
# 169     0.273684  1.209302
# 170     0.336842  1.103448
# 171     0.442105  1.076923
# 236     0.210526  1.000000
# 237     0.263158  0.416667
# 259     0.394737  2.027027
# 263     0.605263  1.352941
# 270     0.684211  1.444444
# 276     0.315789  1.500000
# 277     0.447368  1.416667
# 278     0.631579  1.714286
# 279     0.842105  2.000000
# 352     0.315789  1.500000
# 353     0.526316  1.428571
# 354     0.631579  1.200000
# 355     0.447368  0.607143
# 435     0.305263  1.318182
# 436     0.410526  1.500000
# 437     0.547368  1.464789
# 518     0.500000  1.417910
# 542     0.473684  0.849057
# 557     0.331579  1.400000
# 558     0.489474  1.690909
# 559     0.647368  1.892308
# 572     0.278947  1.104167
# 573     0.515789  1.555556
# 614     0.473684  2.000000
# 615     0.736842  2.545455
# 616     0.157895  0.285714
# 692     0.510526  1.469697
# 721     0.236842  1.125000
# 722     0.310526  1.017241
# 723     0.363158  0.958333
# 730     0.384211  1.327273
# 731     0.426316  1.140845
# 735     0.263158  0.862069
# 736     0.357895  0.944444
# 799     0.578947  0.916667

# %%
# Notice that the condition doesn't need to be numerical.
pokemon_df[(pokemon_df['Type 1'] == 'Ice')&(pokemon_df['Type 2'] == 'Psychic')]
# Out:
#        #      Name Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 133  124      Jynx    Ice  Psychic    455  65      50       35      115
# 257  238  Smoochum    Ice  Psychic    305  45      30       15       85
#
#      Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  Atk_Percent   Atk/Def
# 133       95     95           1      False         150     0.263158  1.428571
# 257       65     65           2      False          90     0.157895  2.000000

# %% [markdown]
# Exercise: how do we measure how many entries satisfy the stated condition above? I.e., what is the length of the dataframe. [hint](https://www.w3schools.com/python/gloss_python_string_length.asp)

# %%
len(pokemon_df[(pokemon_df['Type 1'] == 'Ice')&(pokemon_df['Type 2'] == 'Psychic')])
# Out:
# 2

# %% [markdown]
# Examples on how to sort the dataframe.

# %%
# Use this to show the largest imbalances on attack/defense.
pokemon_df.sort_values(by=['Atk/Def'])[0:10]
# Out:
#        #                   Name Type 1   Type 2  Total   HP  Attack  Defense  \
# 230  213                Shuckle    Bug     Rock    505   20      10      230
# 139  129               Magikarp  Water      NaN    200   20      10       55
# 484  436                Bronzor  Steel  Psychic    300   57      24       86
# 103   95                   Onix   Rock   Ground    385   35      45      160
# 616  555     DarmanitanZen Mode   Fire  Psychic    540  105      30      105
# 189  175                 Togepi  Fairy      NaN    245   35      20       65
# 456  411              Bastiodon   Rock    Steel    495   60      52      168
# 323  299               Nosepass   Rock      NaN    375   30      45      135
# 751  681  AegislashShield Forme  Steel    Ghost    520   60      50      150
# 773  703                Carbink   Rock    Fairy    500   50      50      150
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  Atk_Percent  \
# 230       10      230      5           2      False         260     0.052632
# 139       15       20     80           1      False          85     0.052632
# 484       24       86     23           4      False         167     0.126316
# 103       30       45     70           1      False         240     0.236842
# 616      140      105     55           5      False         240     0.157895
# 189       40       65     20           2      False         120     0.105263
# 456       47      138     30           4      False         280     0.273684
# 323       45       90     30           3      False         210     0.236842
# 751       50      150     60           6      False         260     0.263158
# 773       50      150     50           6      False         250     0.263158
#
#       Atk/Def
# 230  0.043478
# 139  0.181818
# 484  0.279070
# 103  0.281250
# 616  0.285714
# 189  0.307692
# 456  0.309524
# 323  0.333333
# 751  0.333333
# 773  0.333333

# %%
pokemon_df.sort_values(by=['Atk/Def'], ascending=False)[0:10]
# Out:
#        #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386     DeoxysAttack Forme   Psychic     NaN    600  50     180       20
# 347  318               Carvanha     Water    Dark    305  45      90       20
# 19    15  BeedrillMega Beedrill       Bug  Poison    495  65     150       40
# 453  408               Cranidos      Rock     NaN    350  67     125       40
# 348  319               Sharpedo     Water    Dark    460  70     120       40
# 428  386     DeoxysNormal Forme   Psychic     NaN    600  50     150       50
# 750  681   AegislashBlade Forme     Steel   Ghost    520  60     150       50
# 454  409              Rampardos      Rock     NaN    495  97     165       60
# 798  720     HoopaHoopa Unbound   Psychic    Dark    680  80     160       60
# 186  172                  Pichu  Electric     NaN    205  20      40       15
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  Atk_Percent  \
# 429      180       20    150           3       True         250     0.947368
# 347       65       20     65           3      False         155     0.473684
# 19        15       80    145           1      False         255     0.789474
# 453       30       30     58           4      False         232     0.657895
# 348       95       40     95           3      False         230     0.631579
# 428      150       50    150           3       True         250     0.789474
# 750      150       50     60           6      False         260     0.789474
# 454       65       50     58           4      False         322     0.868421
# 798      170      130     80           6       True         300     0.842105
# 186       35       35     60           2      False          75     0.210526
#
#       Atk/Def
# 429  9.000000
# 347  4.500000
# 19   3.750000
# 453  3.125000
# 348  3.000000
# 428  3.000000
# 750  3.000000
# 454  2.750000
# 798  2.666667
# 186  2.666667

# %% [markdown]
# Exercise: how many pokemons don't have a second type? [hint](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html)
#
# What fraction of the dataset do they represent?

# %%
pokemon_df['Type 2'].isna().value_counts()

# OR

len(pokemon_df[(pokemon_df['Type 2'].isna())])
# Out:
# 386

# %%
(len(pokemon_df[(pokemon_df['Type 2'].isna())]) / len(pokemon_df))*100
# Out:
# 48.25

# %% [markdown]
# Now numbers can be quite confusing and their significance is limited when context or comparissons are not offered. In this sense pandas dataframes also contain many built-in functions that can help you. For example:

# %%
pokemon_df['Attack'].describe()
# Out:
# count    800.000000
# mean      79.001250
# std       32.457366
# min        5.000000
# 25%       55.000000
# 50%       75.000000
# 75%      100.000000
# max      190.000000
# Name: Attack, dtype: float64

# %%
pokemon_df.hist()
# Out:
# array([[<Axes: title={'center': '#'}>, <Axes: title={'center': 'Total'}>,
#         <Axes: title={'center': 'HP'}>],
#        [<Axes: title={'center': 'Attack'}>,
#         <Axes: title={'center': 'Defense'}>,
#         <Axes: title={'center': 'Sp. Atk'}>],
#        [<Axes: title={'center': 'Sp. Def'}>,
#         <Axes: title={'center': 'Speed'}>,
#         <Axes: title={'center': 'Generation'}>],
#        [<Axes: title={'center': 'Atk+Def+HP'}>,
#         <Axes: title={'center': 'Atk_Percent'}>,
#         <Axes: title={'center': 'Atk/Def'}>]], dtype=object)

# %% [markdown]
# Exploring the built in histogram method.

# %%
# This plots the histogram of the attack column
pokemon_df.hist('Attack')
# Out:
# array([[<Axes: title={'center': 'Attack'}>]], dtype=object)

# %% [markdown]
# Exploring a line plot.

# %%
pokemon_df['Attack'].plot()
# Out:
# <Axes: >

# %%
# Plotting the first 20 points only.
pokemon_df['Attack'][0:20].plot()
# Out:
# <Axes: >

# %% [markdown]
# Question, is this plot appropriate for this data?
#
# Now look at the following scatter plot.

# %%
pokemon_df.plot.scatter(x='#',y='Attack')
# Out:
# <Axes: xlabel='#', ylabel='Attack'>

# %% [markdown]
# What's the difference between a plot and a scatter plot?

# %%
pokemon_df.plot.scatter(x='Attack',y='Defense')
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# What relevant information can we extract from this sort of plot? what is the use of scattering a column agains't the other?
#
# Further modifying figures with matplotlib.

# %%
# Create figure object and defining axes.
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))

fig.suptitle('This is the title!')

# Above all, notice the ax = ax[0,0].
pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, c='black', ax=axes[0,0])
pokemon_df.plot.scatter(x='Attack',y='Defense', ax=axes[1,0])
pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, c='black', ax=axes[0,1])
pokemon_df.plot.scatter(x='Attack',y='Defense', s=1, ax=axes[1,1])
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# Exercise: for every pokemon type make a scatter plot of attack vs defense (and do colour them differently).

# %%
fig, axes = plt.subplots(nrows=9, ncols=2, figsize=(10, 40))

fig.suptitle('Attack vs Defence by Type')

pokemon_df[pokemon_df['Type 1'] == 'Grass'].plot.scatter(x='Attack',y='Defense',s=5, label='Grass', c="Green", ax=axes[0,0])
pokemon_df[pokemon_df['Type 1'] == 'Fire'].plot.scatter(x='Attack',y='Defense',s=1, label='Fire', c="Red", ax=axes[0,1])
pokemon_df[pokemon_df['Type 1'] == 'Water'].plot.scatter(x='Attack',y='Defense',s=1, label='Water', c="Blue", ax=axes[1,0])
pokemon_df[pokemon_df['Type 1'] == 'Bug'].plot.scatter(x='Attack',y='Defense',s=1, label='Bug', c="DarkGreen", ax=axes[1,1])
pokemon_df[pokemon_df['Type 1'] == 'Normal'].plot.scatter(x='Attack',y='Defense',s=1, label='Normal', c="Khaki", ax=axes[2,0])
pokemon_df[pokemon_df['Type 1'] == 'Poison'].plot.scatter(x='Attack',y='Defense',s=1, label='Poison', c="lime", ax=axes[2,1])
pokemon_df[pokemon_df['Type 1'] == 'Electric'].plot.scatter(x='Attack',y='Defense',s=1, label='Electric', c="yellow", ax=axes[3,0])
pokemon_df[pokemon_df['Type 1'] == 'Ground'].plot.scatter(x='Attack',y='Defense',s=1, label='Ground', c="brown", ax=axes[3,1])
pokemon_df[pokemon_df['Type 1'] == 'Fairy'].plot.scatter(x='Attack',y='Defense',s=1, label='Fairy', c="Pink", ax=axes[4,0])
pokemon_df[pokemon_df['Type 1'] == 'Fighting'].plot.scatter(x='Attack',y='Defense',s=1, label='Fighting', c="sandybrown", ax=axes[4,1])
pokemon_df[pokemon_df['Type 1'] == 'Psychic'].plot.scatter(x='Attack',y='Defense',s=1, label='Psychic', c="purple", ax=axes[5,0])
pokemon_df[pokemon_df['Type 1'] == 'Rock'].plot.scatter(x='Attack',y='Defense',s=1, label='Rock', c="saddlebrown", ax=axes[5,1])
pokemon_df[pokemon_df['Type 1'] == 'Ghost'].plot.scatter(x='Attack',y='Defense',s=1, label='Ghost', c="darkslateblue", ax=axes[6,0])
pokemon_df[pokemon_df['Type 1'] == 'Ice'].plot.scatter(x='Attack',y='Defense',s=1, label='Ice', c="cyan", ax=axes[6,1])
pokemon_df[pokemon_df['Type 1'] == 'Dragon'].plot.scatter(x='Attack',y='Defense',s=1, label='Dragon', c="lightcoral", ax=axes[7,0])
pokemon_df[pokemon_df['Type 1'] == 'Dark'].plot.scatter(x='Attack',y='Defense',s=1, label='Dark', c="dimgrey", ax=axes[7,1])
pokemon_df[pokemon_df['Type 1'] == 'Steel'].plot.scatter(x='Attack',y='Defense',s=1, label='Steel', c="slategrey", ax=axes[8,0])
pokemon_df[pokemon_df['Type 1'] == 'Flying'].plot.scatter(x='Attack',y='Defense',s=1, label='Flying', c="lightgray", ax=axes[8,1])
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %%
# My solution.
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

for key in pokemon_df['Type 1'].unique():
    print(key)

    axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == key]['Attack'],
                 y=pokemon_df[pokemon_df['Type 1'] == key]['Defense'],
                s=5,
                label=key)
    
    plt.legend()
# Out:
# Grass
# Fire
# Water
# Bug
# Normal
# Poison
# Electric
# Ground
# Fairy
# Fighting
# Psychic
# Rock
# Ghost
# Ice
# Dragon
# Dark
# Steel
# Flying

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Defense'],
             s=5, 
             color='red',
             label="Fire")

axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Defense'],
             s=5, 
             color='green',
             label="Grass")

plt.legend()

#pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, c='black', ax=axes[0])
#pokemon_df.plot.scatter(x='Attack',y='Defense',s=1, ax=axes[0])

# %% [markdown]
# A complete guide on the methods that can be acessed in a dataframe object can be found [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html).
#
# Exercise: now do the histogram of the HP, defense and speed columns.

# %%
pokemon_df['HP'].plot.hist()
pokemon_df['Defense'].plot.hist()
pokemon_df['Speed'].plot.hist()
plt.legend()

# %%
pokemon_df['HP'].plot.hist()

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(12,6))
pokemon_df['HP'].plot.hist(ax=axes[0], bins=50, alpha=0.5, color='red')
axes[0].set_title('HP')

pokemon_df['Defense'].plot.hist(ax=axes[1], bins=50, alpha=.5, color='red')
pokemon_df['Attack'].plot.hist(ax=axes[1], bins=50, alpha=.5, color='blue')
axes[1].set_title('Attack & Defense')

pokemon_df['Speed'].plot.hist(ax=axes[2], bins=50, alpha=0.5, color='green')
axes[2].set_title('Speed')

axes[1].set_ylabel('')
axes[2].set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(12,6))
pokemon_df['HP'].plot.hist(ax=axes[0], bins=50, alpha=0.5, color='red')
axes[0].set_title('HP')

pokemon_df['Defense'].plot.hist(ax=axes[1], bins=50, alpha=0.5, color='grey')
axes[1].set_title('Defense')

pokemon_df['Speed'].plot.hist(ax=axes[2], bins=50, alpha=0.5, color='green')
axes[2].set_title('Speed')
# Out:
# Text(0.5, 1.0, 'Speed')

# %% [markdown]
# Numpy can also be used in conjunction with pandas to study the dataframes. For example

# %%
# Returns the maximum value of the pokemons HP.
np.max(pokemon_df['HP'])
# Out:
# 255

# %%
# Returns the mean value of the pokemons attack.
np.mean(pokemon_df['Attack'])
# Out:
# 79.00125

# %% [markdown]
# Exercise: Find out how many pokemons have their Attack stat above the average value for the entire set.

# %%
len(pokemon_df[pokemon_df['Attack'] > np.mean(pokemon_df['Attack'])])
# Out:
# 378

# %% [markdown]
# Another thing that is very common to find is missing entries and there are different stragies that can be employed (for [example](https://pandas.pydata.org/docs/user_guide/missing_data.html)). Using [dropna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html) we can drop all the rows that have a missing value,

# %%
pokemon_df.dropna()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  Atk_Percent  \
# 0         65       65     45           1      False         143     0.257895
# 1         80       80     60           1      False         185     0.326316
# 2        100      100     80           1      False         245     0.431579
# 3        122      120     80           1      False         303     0.526316
# 6        109       85    100           1      False         240     0.442105
# ..       ...      ...    ...         ...        ...         ...          ...
# 795      100      150     50           6       True         300     0.526316
# 796      160      110    110           6       True         320     0.842105
# 797      150      130     70           6       True         250     0.578947
# 798      170      130     80           6       True         300     0.842105
# 799      130       90     70           6       True         310     0.578947
#
#       Atk/Def
# 0    1.000000
# 1    0.984127
# 2    0.987952
# 3    0.813008
# 6    1.076923
# ..        ...
# 795  0.666667
# 796  1.454545
# 797  1.833333
# 798  2.666667
# 799  0.916667
#
# [414 rows x 16 columns]

# %% [markdown]
# Why all the dataframe was wipped out?

# %% [markdown]
# Columns can be individually dropped using [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)

# %%
pokemon_df.keys()
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Atk+Def+HP',
#        'Atk_Percent', 'Atk/Def'],
#       dtype='object')

# %%
# For example:
pokemon_df.drop(['Atk_Percent','Atk/Def', 'Atk+Def+HP'], axis=1)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
pokemon_df = pokemon_df.drop(['Irrelevant','HP+100'], axis=1)
# Now the NANs are not in every row anymore! see the result.
pokemon_df.dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\Chris\iCloudDrive\Code Cumbria\Python\Data Science\Pandas.ipynb Cell 101 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Chris/iCloudDrive/Code%20Cumbria/Python/Data%20Science/Pandas.ipynb#Y165sZmlsZQ%3D%3D?line=0'>1</a> pokemon_df = pokemon_df.drop(['Irrelevant','HP+100'], axis=1)
#       <a href='vscode-notebook-cell:/e%3A/Chris/iCloudDrive/Code%20Cumbria/Python/Data%20Science/Pandas.ipynb#Y165sZmlsZQ%3D%3D?line=1'>2</a> # Now the NANs are not in every row anymore! see the result.
#       <a href='vscode-notebook-cell:/e%3A/Chris/iCloudDrive/Code%20Cumbria/Python/Data%20Science/Pandas.ipynb#Y165sZmlsZQ%3D%3D?line=2'>3</a> pokemon_df.dropna()
#
# File f:\Python3120\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File f:\Python3120\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File f:\Python3120\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File f:\Python3120\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['Irrelevant', 'HP+100'] not found in axis"

# %% [markdown]
# Exercise: compare the lengths of the dataframe before and after dropping the missing values.

# %% [markdown]
# Question: When is it appropriated to drop the missing values?

# %% [markdown]
# Exercise: make a pie chart showcasing the distribution of pokemon types.

# %% [markdown]
# Exercise: which is the strongest pokemon?

# %% [markdown]
# Exercise: what is a boxplot?

# %% [markdown]
# Exercise: make a box plot showcasing the different pokemon attacks.

# %% [markdown]
# If you want to dive into pandas and machine learning I recommend using [Kaggle](https://www.kaggle.com/). This platform contains a multitude of interactive tutorials that can facilitate your learning process.

# %%
import seaborn as sns

sns.set()

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Fire']['Defense'],
             s=1, 
             color='red')
axes.scatter(x=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Attack'],
             y=pokemon_df[pokemon_df['Type 1'] == 'Grass']['Defense'],
             s=1, 
             color='green')

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation  Atk+Def+HP  Atk_Percent     Atk/Def
# count  800.000000  800.000000   800.00000  800.000000   800.000000  800.000000
# mean    71.902500   68.277500     3.32375  222.102500     0.415796    1.164547
# std     27.828916   29.060474     1.66129   68.173834     0.170828    0.552604
# min     20.000000    5.000000     1.00000   55.000000     0.026316    0.043478
# 25%     50.000000   45.000000     2.00000  170.000000     0.289474    0.828771
# 50%     70.000000   65.000000     3.00000  222.000000     0.394737    1.074176
# 75%     90.000000   90.000000     5.00000  269.250000     0.526316    1.416667
# max    230.000000  180.000000     6.00000  440.000000     1.000000    9.000000

# %%
sns.boxplot(x=pokemon_df['Attack'])
# Out:
# <Axes: xlabel='Attack'>

# %%
pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# Out:
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# ...
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# C:\Users\cjecc\AppData\Local\Temp\ipykernel_8200\2031770290.py:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pokemon_df['Type 1'].apply(pd.value_counts).plot.pie(subplots=True)
# array([<Axes: ylabel='Grass'>, <Axes: ylabel='Fire'>,
#        <Axes: ylabel='Water'>, <Axes: ylabel='Bug'>,
#        <Axes: ylabel='Normal'>, <Axes: ylabel='Poison'>,
#        <Axes: ylabel='Electric'>, <Axes: ylabel='Ground'>,
#        <Axes: ylabel='Fairy'>, <Axes: ylabel='Fighting'>,
#        <Axes: ylabel='Psychic'>, <Axes: ylabel='Rock'>,
#        <Axes: ylabel='Ghost'>, <Axes: ylabel='Ice'>,
#        <Axes: ylabel='Dragon'>, <Axes: ylabel='Dark'>,
#        <Axes: ylabel='Steel'>, <Axes: ylabel='Flying'>], dtype=object)
# Error in callback <function flush_figures at 0x00000223E4995080> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~\AppData\Roaming\Python\Python312\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File f:\Python3120\Lib\site-packages\matplotlib\backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File f:\Python3120\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File f:\Python3120\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File f:\Python3120\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File f:\Python3120\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File f:\Python3120\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File f:\Python3120\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File f:\Python3120\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File f:\Python3120\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File f:\Python3120\Lib\site-packages\matplotlib\legend.py:769, in Legend.draw(self, renderer)
#     765     self._legend_box.set_width(self.get_bbox_to_anchor().width - pad)
#     767 # update the location and size of the legend. This needs to
#     768 # be done in any case to clip the figure right.
# --> 769 bbox = self._legend_box.get_window_extent(renderer)
#     770 self.legendPatch.set_bounds(bbox.bounds)
#     771 self.legendPatch.set_mutation_scale(fontsize)
#
# File f:\Python3120\Lib\site-packages\matplotlib\offsetbox.py:401, in OffsetBox.get_window_extent(self, renderer)
#     399 bbox = self.get_bbox(renderer)
#     400 try:  # Some subclasses redefine get_offset to take no args.
# --> 401     px, py = self.get_offset(bbox, renderer)
#     402 except TypeError:
#     403     px, py = self.get_offset()
#
# File f:\Python3120\Lib\site-packages\matplotlib\offsetbox.py:60, in _compat_get_offset.<locals>.get_offset(self, *args, **kwargs)
#      56 params = _api.select_matching_signature(sigs, self, *args, **kwargs)
#      57 bbox = (params["bbox"] if "bbox" in params else
#      58         Bbox.from_bounds(-params["xdescent"], -params["ydescent"],
#      59                          params["width"], params["height"]))
# ---> 60 return meth(params["self"], bbox, params["renderer"])
#
# File f:\Python3120\Lib\site-packages\matplotlib\offsetbox.py:312, in OffsetBox.get_offset(self, bbox, renderer)
#     297 @_compat_get_offset
#     298 def get_offset(self, bbox, renderer):
#     299     """
#     300     Return the offset as a tuple (x, y).
#     301
#    (...)
#     309     renderer : `.RendererBase` subclass
#     310     """
#     311     return (
# --> 312         self._offset(bbox.width, bbox.height, -bbox.x0, -bbox.y0, renderer)
#     313         if callable(self._offset)
#     314         else self._offset)
#
# File f:\Python3120\Lib\site-packages\matplotlib\legend.py:738, in Legend._findoffset(self, width, height, xdescent, ydescent, renderer)
#     735 """Helper function to locate the legend."""
#     737 if self._loc == 0:  # "best".
# --> 738     x, y = self._find_best_position(width, height, renderer)
#     739 elif self._loc in Legend.codes.values():  # Fixed location.
#     740     bbox = Bbox.from_bounds(0, 0, width, height)
#
# File f:\Python3120\Lib\site-packages\matplotlib\legend.py:1186, in Legend._find_best_position(self, width, height, renderer, consider)
#    1183 badness = 0
#    1184 # XXX TODO: If markers are present, it would be good to take them
#    1185 # into account when checking vertex overlaps in the next line.
# -> 1186 badness = (sum(legendBox.count_contains(line.vertices)
#    1187                for line in lines)
#    1188            + legendBox.count_contains(offsets)
#    1189            + legendBox.count_overlaps(bboxes)
#    1190            + sum(line.intersects_bbox(legendBox, filled=False)
#    1191                  for line in lines))
#    1192 if badness == 0:
#    1193     return l, b
#
# File f:\Python3120\Lib\site-packages\matplotlib\legend.py:1186, in <genexpr>(.0)
#    1183 badness = 0
#    1184 # XXX TODO: If markers are present, it would be good to take them
#    1185 # into account when checking vertex overlaps in the next line.
# -> 1186 badness = (sum(legendBox.count_contains(line.vertices)
#    1187                for line in lines)
#    1188            + legendBox.count_contains(offsets)
#    1189            + legendBox.count_overlaps(bboxes)
#    1190            + sum(line.intersects_bbox(legendBox, filled=False)
#    1191                  for line in lines))
#    1192 if badness == 0:
#    1193     return l, b
#
# File f:\Python3120\Lib\site-packages\matplotlib\transforms.py:582, in BboxBase.count_contains(self, vertices)
#     580 vertices = np.asarray(vertices)
#     581 with np.errstate(invalid='ignore'):
# --> 582     return (((self.min < vertices) &
#     583              (vertices < self.max)).all(axis=1).sum())
#
# File f:\Python3120\Lib\site-packages\matplotlib\transforms.py:325, in BboxBase.min(self)
#     322 @property
#     323 def min(self):
#     324     """The bottom-left corner of the bounding box."""
# --> 325     return np.min(self.get_points(), axis=0)
#
# File f:\Python3120\Lib\site-packages\numpy\core\fromnumeric.py:2953, in min(a, axis, out, keepdims, initial, where)
#    2836 @array_function_dispatch(_min_dispatcher)
#    2837 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2838         where=np._NoValue):
#    2839     """
#    2840     Return the minimum of an array or minimum along an axis.
#    2841
#    (...)
#    2951     6
#    2952     """
# -> 2953     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2954                           keepdims=keepdims, initial=initial, where=where)
#
# File f:\Python3120\Lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Atk+Def+HP  Atk_Percent  \
# 0       65       65     45           1      False         143     0.257895
# 1       80       80     60           1      False         185     0.326316
# 2      100      100     80           1      False         245     0.431579
# 3      122      120     80           1      False         303     0.526316
# 4       60       50     65           1      False         134     0.273684
#
#     Atk/Def
# 0  1.000000
# 1  0.984127
# 2  0.987952
# 3  0.813008
# 4  1.209302

# %%
pokemon_df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
pokemon_df['Type 1'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

pokemon_df['Type 1'].value_counts().plot(kind='pie', ax=axes[0])

pokemon_df['Type 2'].value_counts().plot(kind='pie', ax=axes[1])

axes[0].set_ylabel('')
axes[1].set_ylabel('')
fig.suptitle('Test')
plt.tight_layout()

# %%
pokemon_df['Type 1'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
